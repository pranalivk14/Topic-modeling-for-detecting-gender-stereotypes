# %%
import os
import string
import pandas as pd
import io 
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %%
#Reading the dataset into a common list

os.chdir("coca")
commonlist=[]
for i in os.listdir():
    
    f = open(i,"r")
    text = f.read()
    
    #splitting on white spaces
    words = text.split() 
    commonlist.append(words)

len(commonlist)
# Out:
# 115

# %%
#replace punction with whitespace

commonlist_no_punct=[]

for sublist in commonlist:
    table = str.maketrans('', '', string.punctuation)
    no_punct = [w.translate(table) for w in sublist]
    commonlist_no_punct.append(no_punct)

# %%
#remove whitespaces

commonlist_no_whitespace = []

for sublist in commonlist_no_punct:
    new_x = [elem for elem in sublist if elem.strip()]
    commonlist_no_whitespace.append(new_x)

# %%
# convert to lower case

commonlist_lcase = []

for sublist in commonlist_no_whitespace:
    x = [word.lower() for word in sublist]
    commonlist_lcase .append(x)

# %%
#removing stopwords

stop_words = set(stopwords.words('english')) 
commonlist_no_stopwords = []

for sublist in commonlist_lcase:
    output = []
    for x in sublist: 
        if x not in stop_words:
            output.append(x)
    commonlist_no_stopwords.append(output)

# %%
# Get the word count of each word

w_count = dict() 

for sublist in commonlist_no_stopwords:
    for word in sublist:
        if word in w_count:
            w_count[word] = w_count[word] + 1
        else:
            w_count[word] = 1

# %%
w_count
# Out:
# {'4000350': 1,
#  'section': 129,
#  'issues': 320,
#  'p': 14230,
#  'allan': 33,
#  'bloom': 18,
#  'wrote': 211,
#  'closing': 57,
#  'american': 796,
#  'mind': 367,
#  'probably': 445,
#  'thinking': 312,
#  'closed': 141,
#  'image': 143,
#  'contraceptive': 7,
#  'still': 1344,
#  'less': 638,
#  'would': 4152,
#  'anyone': 263,
#  'likely': 334,
#  'think': 2338,
#  'open': 486,
#  'way': 1773,
#  'precisely': 57,
#  'seemed': 331,
#  'govern': 8,
#  'series': 333,
#  'events': 154,
#  'princeton': 50,
#  'university': 507,
#  'past': 561,
#  'year': 1439,
#  'culminated': 5,
#  'dismissal': 19,
#  'one': 5047,
#  'official': 116,
#  'catholic': 132,
#  'chaplains': 1,
#  '1': 1139,
#  'c': 175,
#  'john': 420,
#  'mccloskey': 61,
#  'young': 639,
#  'priest': 76,
#  'belongs': 16,
#  'opus': 38,
#  'dei': 39,
#  'work': 1183,
#  'god': 470,
#  'mixed': 50,
#  'layclerical': 1,
#  'organization': 172,
#  'founded': 33,
#  'spain': 31,
#  '1920s': 14,
#  'branches': 26,
#  'throughout': 129,
#  'world': 1459,
#  'prides': 2,
#  'loyalty': 43,
#  'pope': 30,
#  'rigorous': 12,
#  'spiritual': 67,
#  'discipline': 49,
#  'members': 312,
#  'active': 82,
#  'franco': 11,
#  'government': 588,
#  'group': 543,
#  'often': 568,
#  'accused': 69,
#  'conservative': 180,
#  'political': 528,
#  'ideology': 32,
#  'officially': 31,
#  'states': 798,
#  'position': 292,
#  'free': 357,
#  'engage': 46,
#  'activity': 86,
#  'known': 343,
#  'politically': 50,
#  'years': 1980,
#  'habit': 39,
#  'establishing': 26,
#  'houses': 80,
#  'near': 255,
#  'elite': 47,
#  'universities': 67,
#  'seems': 349,
#  'recruit': 15,
#  'new': 2681,
#  'primarily': 76,
#  'environments': 21,
#  'degrees': 53,
#  'affiliation': 62,
#  'relatively': 122,
#  'loose': 68,
#  'early': 472,
#  '1987': 101,
#  '1989': 113,
#  'purchased': 24,
#  'house': 771,
#  'campus': 66,
#  'serve': 130,
#  'local': 301,
#  'headquarters': 31,
#  'purchase': 50,
#  'alarmed': 9,
#  'princetonians': 1,
#  'indicating': 32,
#  'intended': 69,
#  'become': 583,
#  'permanent': 53,
#  'presence': 129,
#  'almost': 568,
#  'beginning': 204,
#  'rumors': 12,
#  'alleged': 28,
#  'hidden': 49,
#  'agenda': 58,
#  'circulated': 7,
#  'noncatholic': 2,
#  'circles': 40,
#  'community': 319,
#  'among': 550,
#  'liberal': 208,
#  'catholics': 41,
#  'somewhat': 75,
#  'like': 3534,
#  'masons': 1,
#  'earlier': 185,
#  'times': 667,
#  'malign': 2,
#  'secret': 117,
#  'controlling': 20,
#  'tentacles': 5,
#  'moving': 177,
#  'directions': 36,
#  'little': 1136,
#  'ever': 616,
#  'documented': 24,
#  'whatever': 210,
#  'may': 1262,
#  'parts': 100,
#  'clear': 301,
#  'united': 590,
#  'personal': 239,
#  'piety': 2,
#  '1970': 34,
#  '1988': 88,
#  'chaplain': 3,
#  'father': 699,
#  'charles': 149,
#  'weiser': 9,
#  'trenton': 9,
#  'diocesan': 6,
#  'directed': 43,
#  'aquinas': 11,
#  'foundation': 85,
#  'equivalent': 30,
#  'newman': 14,
#  'clubs': 63,
#  'elsewhere': 66,
#  'occupied': 27,
#  'thomas': 241,
#  'mann': 2,
#  'appointed': 27,
#  'bishop': 23,
#  'recognized': 78,
#  'account': 122,
#  'first': 2079,
#  'cool': 109,
#  'describes': 46,
#  'encounters': 13,
#  'friendly': 39,
#  'eventually': 162,
#  'however': 513,
#  'made': 1349,
#  'decision': 226,
#  'appoint': 6,
#  'assistant': 93,
#  'director': 249,
#  'much': 1592,
#  'anything': 535,
#  'according': 322,
#  'keep': 560,
#  'eye': 183,
#  '2': 907,
#  'shortly': 49,
#  'afterwards': 16,
#  'terminated': 5,
#  'relations': 56,
#  'another': 1160,
#  'jesuit': 16,
#  'robert': 138,
#  'ferrick': 6,
#  'disagreements': 12,
#  'policies': 115,
#  'rather': 518,
#  'accept': 84,
#  'left': 873,
#  'departure': 19,
#  'caused': 95,
#  'good': 1541,
#  'deal': 297,
#  'bitterness': 12,
#  'admirers': 9,
#  'running': 366,
#  'dispute': 27,
#  'revealing': 19,
#  'ardent': 9,
#  'attended': 49,
#  'weekly': 39,
#  'midnight': 32,
#  'mass': 106,
#  'celebrated': 30,
#  'referred': 41,
#  'druids': 2,
#  'leftwing': 9,
#  'journalist': 30,
#  'gloria': 10,
#  'emerson': 2,
#  'noted': 98,
#  'something': 1091,
#  'remarkable': 61,
#  'must': 779,
#  'going': 2170,
#  'get': 2196,
#  'jewish': 71,
#  'undergraduate': 41,
#  'puerto': 5,
#  'rican': 3,
#  'methodist': 5,
#  'sic': 3,
#  'agnostic': 7,
#  'together': 420,
#  'worship': 19,
#  'service': 228,
#  '3': 487,
#  'farewell': 21,
#  'message': 115,
#  'listed': 43,
#  'constituency': 5,
#  'chapel': 8,
#  'colleagues': 115,
#  'black': 500,
#  'latino': 6,
#  'friends': 360,
#  'concerned': 122,
#  'alcohol': 33,
#  'drug': 149,
#  'abuse': 77,
#  'harassed': 8,
#  'marginal': 9,
#  'foreigner': 6,
#  '4': 392,
#  'notably': 18,
#  'absent': 19,
#  'list': 204,
#  'traditional': 150,
#  'occasion': 45,
#  'public': 562,
#  'attacks': 87,
#  'notable': 18,
#  'fact': 605,
#  'major': 462,
#  'scholarly': 23,
#  'communities': 71,
#  'without': 723,
#  'felt': 428,
#  'need': 785,
#  'offer': 187,
#  'proof': 43,
#  'even': 1875,
#  'define': 36,
#  'terms': 199,
#  'thus': 195,
#  'walter': 32,
#  'murphy': 23,
#  'saying': 412,
#  'fascist': 3,
#  'ties': 28,
#  '5': 361,
#  'closest': 42,
#  'critics': 111,
#  'came': 831,
#  'offering': 62,
#  'charges': 80,
#  'frequent': 36,
#  'citing': 12,
#  'book': 447,
#  'people': 2713,
#  'struggle': 79,
#  'catholicism': 9,
#  'viking': 3,
#  'late': 347,
#  'penny': 24,
#  'lernoux': 3,
#  'claims': 95,
#  'involved': 237,
#  'various': 151,
#  'rightwing': 14,
#  'movements': 36,
#  'latin': 49,
#  'america': 468,
#  'hardly': 96,
#  'disinterested': 5,
#  'scholar': 21,
#  'officials': 217,
#  'pointed': 100,
#  'libel': 2,
#  'suit': 84,
#  'west': 233,
#  'german': 51,
#  'court': 311,
#  'cited': 39,
#  'irrefutable': 1,
#  'evidence': 202,
#  'sinister': 3,
#  'nature': 206,
#  'alarm': 15,
#  'fueled': 11,
#  'within': 388,
#  'openness': 12,
#  'rationality': 9,
#  'unlimited': 19,
#  'attention': 252,
#  'press': 211,
#  'frequently': 69,
#  'things': 924,
#  'mention': 73,
#  'failed': 120,
#  'recall': 39,
#  'woman': 828,
#  'found': 711,
#  'murdered': 20,
#  'basement': 24,
#  'despite': 229,
#  'information': 321,
#  'absolutely': 134,
#  'bearing': 33,
#  'controversy': 39,
#  'months': 412,
#  'case': 416,
#  'boil': 21,
#  'related': 142,
#  'worried': 94,
#  'possible': 327,
#  'intentions': 20,
#  'calling': 128,
#  'cultlike': 2,
#  'possessing': 5,
#  'reputation': 69,
#  '6': 267,
#  'particularly': 193,
#  'targeted': 22,
#  'ivy': 16,
#  'league': 355,
#  'charge': 124,
#  'true': 335,
#  'merely': 78,
#  'proved': 63,
#  'accepts': 11,
#  'institutions': 103,
#  'evaluation': 78,
#  'worth': 184,
#  'initially': 46,
#  'unsympathetic': 1,
#  'observed': 52,
#  'irony': 28,
#  'behavior': 155,
#  'highly': 115,
#  'rational': 38,
#  'academics': 32,
#  'guy': 322,
#  'coming': 493,
#  'three': 1224,
#  'week': 741,
#  'paralyzed': 10,
#  'anxiety': 60,
#  'immediate': 47,
#  'feeling': 207,
#  'acting': 54,
#  'elephant': 11,
#  'jumping': 28,
#  'chair': 138,
#  'trying': 495,
#  'away': 882,
#  'mouse': 17,
#  'afraid': 121,
#  'take': 1188,
#  '7': 242,
#  'studiously': 1,
#  'avoided': 31,
#  'inconvenient': 4,
#  'students': 718,
#  'others': 466,
#  'means': 336,
#  'outnumbered': 3,
#  'supporters': 43,
#  'claimed': 67,
#  'considerable': 27,
#  'vehemence': 1,
#  'approach': 191,
#  'religion': 145,
#  'inherently': 12,
#  'offensive': 79,
#  'oppressive': 5,
#  'widely': 83,
#  'enough': 680,
#  'gave': 381,
#  'maximum': 39,
#  'publicity': 23,
#  'follow': 141,
#  'sophisticated': 28,
#  'success': 184,
#  'time': 2672,
#  'forced': 150,
#  'withdraw': 13,
#  'really': 1099,
#  'bothered': 18,
#  'obvious': 99,
#  'reasons': 138,
#  'could': 2791,
#  'admit': 54,
#  'intelligent': 30,
#  'including': 392,
#  'undergraduates': 9,
#  'find': 712,
#  'attractive': 44,
#  'task': 124,
#  'save': 141,
#  'vocal': 14,
#  'critic': 34,
#  'named': 195,
#  'taliercio': 4,
#  'member': 153,
#  'religious': 313,
#  'pax': 6,
#  'christi': 1,
#  'peace': 114,
#  'christ': 60,
#  'constantly': 33,
#  'referring': 35,
#  'supposed': 151,
#  'program': 324,
#  'summer': 267,
#  'lived': 203,
#  'luxurious': 7,
#  'surroundings': 12,
#  '8': 190,
#  'living': 330,
#  'opulence': 1,
#  'grounds': 69,
#  'condemnation': 5,
#  'might': 914,
#  'many': 1552,
#  'damned': 15,
#  'talk': 519,
#  'reported': 171,
#  'direct': 113,
#  'experience': 289,
#  'tried': 274,
#  'influence': 136,
#  'views': 103,
#  'kind': 633,
#  'identifiably': 3,
#  'abortion': 122,
#  'instead': 362,
#  'small': 703,
#  'number': 526,
#  'offended': 10,
#  'church': 291,
#  'calls': 207,
#  'spirituality': 5,
#  'half': 376,
#  'dozen': 86,
#  'identified': 87,
#  'complained': 35,
#  'overly': 13,
#  'negative': 101,
#  'rigid': 18,
#  'censorious': 2,
#  'turned': 473,
#  'mean': 678,
#  'placed': 115,
#  'emphasis': 51,
#  'sin': 22,
#  'warned': 35,
#  'avoid': 140,
#  'certain': 260,
#  'occasions': 27,
#  'suggested': 118,
#  'larger': 123,
#  'classical': 33,
#  'christian': 127,
#  'doctrine': 30,
#  'taught': 89,
#  'protestant': 19,
#  'schools': 166,
#  'indeed': 219,
#  'unattractive': 3,
#  'modern': 143,
#  'americans': 247,
#  'problem': 498,
#  'selfcorrecting': 1,
#  'simply': 287,
#  'mission': 82,
#  'central': 157,
#  'issue': 352,
#  'truly': 105,
#  'pluralistic': 17,
#  'environment': 156,
#  'reject': 30,
#  'advice': 79,
#  'saw': 561,
#  'fit': 110,
#  'go': 1672,
#  'contortions': 2,
#  'conceal': 16,
#  'wanted': 573,
#  'authorities': 59,
#  'suppress': 16,
#  'individual': 223,
#  'whose': 319,
#  'personally': 44,
#  'distasteful': 2,
#  'attempt': 96,
#  'imply': 20,
#  'engaged': 47,
#  'improper': 8,
#  'actions': 65,
#  'female': 113,
#  'student': 311,
#  'claim': 117,
#  'questioned': 30,
#  'confessional': 6,
#  'sexual': 111,
#  'activities': 98,
#  '9': 154,
#  'allegedly': 12,
#  'improprieties': 3,
#  'nadir': 2,
#  'yellow': 107,
#  'journalism': 22,
#  'reached': 175,
#  'given': 390,
#  'sources': 70,
#  'prefer': 64,
#  'remain': 138,
#  'anonymous': 22,
#  'action': 236,
#  '10': 535,
#  'insinuate': 2,
#  'serious': 206,
#  'part': 756,
#  'existed': 26,
#  'suppressed': 5,
#  'intimidated': 14,
#  'complaints': 21,
#  'confidential': 7,
#  'fear': 196,
#  'legal': 173,
#  'logical': 25,
#  'assumption': 31,
#  'unfounded': 1,
#  'withstand': 10,
#  'scrutiny': 19,
#  'unable': 63,
#  'state': 895,
#  'frankly': 35,
#  'sought': 75,
#  'opinions': 38,
#  'next': 1013,
#  'fell': 179,
#  'back': 2109,
#  'narrow': 74,
#  'point': 624,
#  'allowed': 210,
#  'represent': 54,
#  'since': 844,
#  'associate': 48,
#  'distorted': 6,
#  'theology': 19,
#  'prerogative': 2,
#  'ultimately': 72,
#  'decide': 109,
#  'enjoy': 90,
#  'status': 126,
#  'chaplaincy': 1,
#  'later': 666,
#  'stated': 45,
#  'investigated': 22,
#  'every': 975,
#  'complaint': 30,
#  'though': 690,
#  'logic': 30,
#  'viewed': 50,
#  'controversial': 44,
#  'ought': 74,
#  'contention': 13,
#  'defended': 21,
#  'circumstances': 79,
#  'also': 1704,
#  'example': 337,
#  'passionately': 9,
#  'supporting': 40,
#  'sandinistas': 1,
#  'nicaragua': 7,
#  'likelihood': 21,
#  'dubbed': 14,
#  'prophet': 22,
#  'praised': 22,
#  'courage': 36,
#  'nub': 1,
#  'halfconsciously': 1,
#  'expressed': 61,
#  'stamp': 9,
#  'agree': 192,
#  '11': 249,
#  'demanding': 32,
#  'expulsion': 3,
#  'support': 469,
#  'reverse': 41,
#  'effect': 210,
#  'wants': 254,
#  'disagreement': 14,
#  'dilemma': 10,
#  'liberalism': 14,
#  'nutshell': 5,
#  'tolerant': 12,
#  'pluralism': 5,
#  'either': 328,
#  'tolerate': 22,
#  'tolerating': 3,
#  'said': 4524,
#  'originally': 37,
#  'attracted': 39,
#  'provided': 114,
#  'security': 206,
#  'makes': 361,
#  'complicated': 49,
#  'lives': 351,
#  'simple': 167,
#  'everything': 486,
#  'white': 701,
#  'nt': 7027,
#  '12': 288,
#  'curious': 53,
#  'confession': 20,
#  'make': 1509,
#  'prompting': 14,
#  'question': 439,
#  'easily': 151,
#  'manipulated': 11,
#  'know': 2605,
#  'right': 1842,
#  'necessary': 114,
#  'justify': 35,
#  'exercise': 61,
#  'censorship': 15,
#  'full': 307,
#  'freedom': 211,
#  'understanding': 143,
#  'protected': 55,
#  'better': 748,
#  'december': 102,
#  'suzi': 2,
#  'landolphi': 3,
#  'professional': 144,
#  'comedienne': 1,
#  'performed': 43,
#  'routine': 46,
#  'designed': 116,
#  'promote': 64,
#  'safe': 141,
#  'sex': 146,
#  'feminism': 36,
#  'included': 173,
#  'pulling': 72,
#  'male': 128,
#  'front': 431,
#  'video': 132,
#  'camera': 72,
#  'ordering': 15,
#  'say': 1536,
#  'vaginal': 1,
#  'got': 1291,
#  'caught': 202,
#  'throat': 50,
#  'stretch': 74,
#  'condoms': 10,
#  'heads': 89,
#  'desensitizing': 1,
#  'audience': 95,
#  'contraceptives': 4,
#  'subsequently': 19,
#  'published': 127,
#  'letter': 157,
#  'daily': 112,
#  'princetonian': 6,
#  'newspaper': 87,
#  'objecting': 2,
#  'salivating': 1,
#  'animals': 176,
#  'capacity': 59,
#  'selfcontrol': 2,
#  '13': 162,
#  'responded': 73,
#  'accusing': 11,
#  'enslave': 2,
#  'women': 1041,
#  'holy': 79,
#  'bond': 99,
#  'matrimony': 1,
#  'keeping': 115,
#  'barefoot': 9,
#  'pregnant': 59,
#  'kitchen': 132,
#  'illogical': 4,
#  'preaching': 15,
#  'chastity': 3,
#  'concluded': 59,
#  'suggesting': 37,
#  'perhaps': 381,
#  'society': 253,
#  'large': 411,
#  'advise': 14,
#  'drinking': 66,
#  'nothing': 587,
#  'semen': 4,
#  'aids': 69,
#  'patients': 131,
#  '14': 176,
#  'met': 240,
#  'vincent': 46,
#  'keane': 12,
#  'demand': 104,
#  'removal': 19,
#  'remained': 72,
#  'publicly': 31,
#  'noncommital': 1,
#  'let': 911,
#  'using': 367,
#  'name': 445,
#  'following': 258,
#  'thought': 828,
#  'least': 551,
#  'begin': 207,
#  'wonder': 140,
#  'whether': 429,
#  'tone': 63,
#  'debate': 110,
#  'sinking': 15,
#  'lower': 201,
#  'proper': 62,
#  'embarrassed': 36,
#  'rhetoric': 26,
#  'ways': 253,
#  'essence': 31,
#  'matter': 343,
#  'letterwriter': 1,
#  'explicitly': 23,
#  'denied': 63,
#  'entitled': 27,
#  'toleration': 8,
#  'establish': 44,
#  'universal': 44,
#  'hegemonic': 4,
#  'view': 257,
#  'writer': 131,
#  'plural': 3,
#  'democracy': 111,
#  'spread': 99,
#  'assault': 51,
#  'inquiry': 63,
#  'discourses': 3,
#  'speech': 131,
#  'minds': 47,
#  '15': 317,
#  'incident': 63,
#  'revealed': 81,
#  'clearly': 167,
#  'real': 507,
#  'opposition': 53,
#  'therefore': 135,
#  'liberation': 29,
#  'dared': 16,
#  'disagree': 48,
#  'current': 241,
#  'conventional': 41,
#  'wisdom': 32,
#  'intellectual': 67,
#  'described': 109,
#  'purpose': 100,
#  'exclude': 5,
#  'consideration': 28,
#  'unfashionable': 4,
#  'orthodoxy': 14,
#  'root': 37,
#  'tension': 33,
#  'confirmed': 38,
#  'g': 84,
#  'k': 21,
#  'chesterton': 2,
#  'sponsored': 15,
#  'maggie': 13,
#  'gallagher': 11,
#  'author': 217,
#  'arguing': 30,
#  'exploited': 9,
#  'revolution': 57,
#  'faced': 70,
#  'partially': 18,
#  'hostile': 69,
#  'pelted': 4,
#  'stage': 139,
#  'feminist': 72,
#  'review': 112,
#  'stopped': 185,
#  'short': 327,
#  'barred': 11,
#  'appeared': 137,
#  'false': 64,
#  'pretenses': 1,
#  'acknowledge': 31,
#  'supported': 77,
#  'patriarchy': 41,
#  '16': 168,
#  'give': 615,
#  'unmerited': 1,
#  'respectability': 2,
#  'although': 402,
#  'affiliated': 4,
#  'defenders': 14,
#  'soon': 342,
#  'forth': 59,
#  'yet': 619,
#  'barrage': 6,
#  'widened': 6,
#  'include': 179,
#  'defend': 56,
#  'techniques': 40,
#  'classic': 67,
#  'mccarthyism': 9,
#  'ceaselessly': 1,
#  'repeated': 40,
#  'offered': 141,
#  'unsubstantiated': 2,
#  'unnamed': 2,
#  'hints': 6,
#  'impossible': 104,
#  'situation': 227,
#  'cult': 23,
#  'repeatedly': 33,
#  'criticized': 31,
#  'investigating': 29,
#  'luis': 31,
#  'tellez': 2,
#  'head': 660,
#  'filed': 41,
#  'formal': 41,
#  'resulted': 28,
#  'investigation': 103,
#  'weapon': 36,
#  'unceasing': 2,
#  'propaganda': 22,
#  'seem': 271,
#  'calculated': 26,
#  'correctly': 25,
#  'achieve': 43,
#  'goal': 122,
#  'obligation': 25,
#  'prove': 87,
#  'concerning': 50,
#  'matters': 75,
#  'began': 492,
#  'claiming': 32,
#  'taking': 344,
#  'particular': 189,
#  'courses': 66,
#  'prohibited': 7,
#  'reading': 192,
#  'books': 205,
#  'forbidden': 17,
#  'read': 442,
#  'works': 172,
#  'asserted': 15,
#  'education': 339,
#  'fundamentally': 20,
#  'odds': 61,
#  'turn': 409,
#  'allegations': 25,
#  'untrue': 6,
#  'smoking': 32,
#  'gun': 163,
#  'attempted': 31,
#  'murder': 59,
#  'memo': 28,
#  'listing': 8,
#  'forty': 33,
#  'interest': 259,
#  'culture': 282,
#  'viewpoint': 5,
#  '17': 135,
#  'drawn': 66,
#  'directly': 137,
#  'catalogue': 3,
#  'nine': 147,
#  'academic': 204,
#  'departments': 28,
#  'net': 55,
#  'cast': 89,
#  'wide': 145,
#  'islam': 33,
#  'origins': 18,
#  'science': 178,
#  'criticism': 69,
#  'centered': 13,
#  'note': 118,
#  'appended': 4,
#  'remember': 352,
#  'depends': 55,
#  'outlook': 22,
#  'teacher': 138,
#  'giving': 167,
#  'course': 630,
#  'latter': 45,
#  'quite': 262,
#  'interesting': 134,
#  'stimulating': 6,
#  'impact': 134,
#  'counterproductive': 4,
#  'warning': 55,
#  'trumpeted': 2,
#  'worst': 124,
#  'violation': 24,
#  'omitted': 10,
#  'censoring': 2,
#  'unacceptable': 21,
#  'face': 564,
#  'recommendation': 14,
#  'indication': 20,
#  'considered': 185,
#  'antichristian': 3,
#  'different': 638,
#  'feminists': 19,
#  'militant': 12,
#  'ethnic': 75,
#  'minorities': 36,
#  'campuses': 10,
#  'assert': 10,
#  'evaluate': 26,
#  'mildly': 10,
#  'obliquely': 10,
#  'end': 738,
#  'last': 1722,
#  'march': 171,
#  'six': 454,
#  'tactics': 31,
#  'intimidation': 6,
#  'detrimental': 4,
#  'names': 100,
#  'portrayed': 17,
#  'fostering': 4,
#  'ignorance': 9,
#  'contrast': 65,
#  'valued': 19,
#  'knowledge': 144,
#  'consistently': 39,
#  'marred': 2,
#  'elementary': 41,
#  'errors': 30,
#  'petition': 26,
#  'historian': 25,
#  'carl': 71,
#  'schorske': 2,
#  'spelled': 4,
#  'scherske': 1,
#  'bertram': 1,
#  'russell': 25,
#  'issued': 49,
#  'detailed': 27,
#  'response': 185,
#  'mentioning': 9,
#  'lodged': 7,
#  'statements': 61,
#  'attributed': 23,
#  'authentic': 13,
#  'constant': 51,
#  'disadvantage': 7,
#  'used': 778,
#  'defense': 269,
#  'mount': 56,
#  'aggressively': 19,
#  'tactic': 22,
#  'willing': 129,
#  'permit': 34,
#  'twenty': 90,
#  ...}

# %%
#Eliminate the words with count less than 10

new_dict = {key : value for (key, value) in w_count.items() if value > 9}

# %%
print (new_dict)
# Out:
# {'section': 129, 'issues': 320, 'p': 14230, 'allan': 33, 'bloom': 18, 'wrote': 211, 'closing': 57, 'american': 796, 'mind': 367, 'probably': 445, 'thinking': 312, 'closed': 141, 'image': 143, 'still': 1344, 'less': 638, 'would': 4152, 'anyone': 263, 'likely': 334, 'think': 2338, 'open': 486, 'way': 1773, 'precisely': 57, 'seemed': 331, 'series': 333, 'events': 154, 'princeton': 50, 'university': 507, 'past': 561, 'year': 1439, 'dismissal': 19, 'one': 5047, 'official': 116, 'catholic': 132, '1': 1139, 'c': 175, 'john': 420, 'mccloskey': 61, 'young': 639, 'priest': 76, 'belongs': 16, 'opus': 38, 'dei': 39, 'work': 1183, 'god': 470, 'mixed': 50, 'organization': 172, 'founded': 33, 'spain': 31, '1920s': 14, 'branches': 26, 'throughout': 129, 'world': 1459, 'loyalty': 43, 'pope': 30, 'rigorous': 12, 'spiritual': 67, 'discipline': 49, 'members': 312, 'active': 82, 'franco': 11, 'government': 588, 'group': 543, 'often': 568, 'accused': 69, 'conservative': 180, 'political': 528, 'ideology': 32, 'officially': 31, 'states': 798, 'position': 292, 'free': 357, 'engage': 46, 'activity': 86, 'known': 343, 'politically': 50, 'years': 1980, 'habit': 39, 'establishing': 26, 'houses': 80, 'near': 255, 'elite': 47, 'universities': 67, 'seems': 349, 'recruit': 15, 'new': 2681, 'primarily': 76, 'environments': 21, 'degrees': 53, 'affiliation': 62, 'relatively': 122, 'loose': 68, 'early': 472, '1987': 101, '1989': 113, 'purchased': 24, 'house': 771, 'campus': 66, 'serve': 130, 'local': 301, 'headquarters': 31, 'purchase': 50, 'indicating': 32, 'intended': 69, 'become': 583, 'permanent': 53, 'presence': 129, 'almost': 568, 'beginning': 204, 'rumors': 12, 'alleged': 28, 'hidden': 49, 'agenda': 58, 'circles': 40, 'community': 319, 'among': 550, 'liberal': 208, 'catholics': 41, 'somewhat': 75, 'like': 3534, 'earlier': 185, 'times': 667, 'secret': 117, 'controlling': 20, 'moving': 177, 'directions': 36, 'little': 1136, 'ever': 616, 'documented': 24, 'whatever': 210, 'may': 1262, 'parts': 100, 'clear': 301, 'united': 590, 'personal': 239, '1970': 34, '1988': 88, 'father': 699, 'charles': 149, 'directed': 43, 'aquinas': 11, 'foundation': 85, 'equivalent': 30, 'newman': 14, 'clubs': 63, 'elsewhere': 66, 'occupied': 27, 'thomas': 241, 'appointed': 27, 'bishop': 23, 'recognized': 78, 'account': 122, 'first': 2079, 'cool': 109, 'describes': 46, 'encounters': 13, 'friendly': 39, 'eventually': 162, 'however': 513, 'made': 1349, 'decision': 226, 'assistant': 93, 'director': 249, 'much': 1592, 'anything': 535, 'according': 322, 'keep': 560, 'eye': 183, '2': 907, 'shortly': 49, 'afterwards': 16, 'relations': 56, 'another': 1160, 'jesuit': 16, 'robert': 138, 'disagreements': 12, 'policies': 115, 'rather': 518, 'accept': 84, 'left': 873, 'departure': 19, 'caused': 95, 'good': 1541, 'deal': 297, 'bitterness': 12, 'running': 366, 'dispute': 27, 'revealing': 19, 'attended': 49, 'weekly': 39, 'midnight': 32, 'mass': 106, 'celebrated': 30, 'referred': 41, 'journalist': 30, 'gloria': 10, 'noted': 98, 'something': 1091, 'remarkable': 61, 'must': 779, 'going': 2170, 'get': 2196, 'jewish': 71, 'undergraduate': 41, 'together': 420, 'worship': 19, 'service': 228, '3': 487, 'farewell': 21, 'message': 115, 'listed': 43, 'colleagues': 115, 'black': 500, 'friends': 360, 'concerned': 122, 'alcohol': 33, 'drug': 149, 'abuse': 77, '4': 392, 'notably': 18, 'absent': 19, 'list': 204, 'traditional': 150, 'occasion': 45, 'public': 562, 'attacks': 87, 'notable': 18, 'fact': 605, 'major': 462, 'scholarly': 23, 'communities': 71, 'without': 723, 'felt': 428, 'need': 785, 'offer': 187, 'proof': 43, 'even': 1875, 'define': 36, 'terms': 199, 'thus': 195, 'walter': 32, 'murphy': 23, 'saying': 412, 'ties': 28, '5': 361, 'closest': 42, 'critics': 111, 'came': 831, 'offering': 62, 'charges': 80, 'frequent': 36, 'citing': 12, 'book': 447, 'people': 2713, 'struggle': 79, 'late': 347, 'penny': 24, 'claims': 95, 'involved': 237, 'various': 151, 'rightwing': 14, 'movements': 36, 'latin': 49, 'america': ...

# %%
print(len(new_dict))
# Out:
# 11453

# %%
#converting new dictionary to list

new_word_list=list(new_dict.keys())

# %%
with open("coca_dict", "w") as outfile:
    for s in new_word_list:
        outfile.write("%s\n" % s)

# %%
#Mapping the words with their resprctive indices

list_after_mapping = []

for sublist in commonlist_no_stopwords:
    elem = {k: i for i, k in enumerate(new_word_list)} 
    Output = list(map(elem.get, sublist)) 
    list_after_mapping.append(Output)

# %%
print(len(list_after_mapping))
# Out:
# 115

# %%
#Eliminating None values from the list

final_output = [] 

for sublist in list_after_mapping:
    output = []
    for x in sublist: 
        if x != None :
            output.append(x)
    final_output.append(output)

# %%
# Making the output compatible for MMSG topic model
# ELiminating brackets and commas

string1 = str(final_output)[1:-1] 
string2 = str(string1)[1:-1] 
string3 = ''.join(string2.split(','))
string4 = '\n'.join(string3.split('['))
Final_file = ''.join(string4.split(']'))

#'Final_file' compatible for MMSG topic model


#Saving Final file
with open("input file for MMSG", "w") as output:
    output.write(str(Final_file))

# %% [markdown]
# # Run the Final_file through the MMSG-TM model.

# %%
#Fetching Top 10 words each topic
# Reading the output file generated from the MMSG Topic Model


df_topic=pd.read_csv("MMSGTM_ForTopics.csv")
df_topic.set_index("WORD", inplace = True) 


#Filter top 10 values for all columns (200 Topics) 

new_df1 = df_topic.apply(lambda s, n: pd.Series(s.nlargest(n).index), axis=0, n=10)

#Saving the result in excel file
new_df1.to_excel (r'top10_words.xlsx', index = True, header=True)

# %%
new_df1
# Out:
#   Topic 1    Topic 2   Topic 3    Topic 4    Topic 5    Topic 6      Topic 7  \
# 0       p          p  narrator       like  announcer          p            p
# 1      nt  religious    barrie        new        rat   students       shelly
# 2   would    liberal         1         nt    grandma        one        petey
# 3     one    freedom         2  voiceover       year      would       purple
# 4      us   academic     white        one          1  education  butterflies
# 5     day  political     peter     idrive        cat  political    butterfly
# 6    said   religion       mrs       many          2       work   collection
# 7    back        one        mr    vanocur    emperor        may        wings
# 8    time      human    sylvia          p    chinese       many      article
# 9    know      moral      play       time         ox       fact    copyright
#
#      Topic 8   Topic 9 Topic 10  ...  Topic 191  Topic 192  Topic 193  \
# 0         nt         p       nt  ...         mr         nt         nt
# 1  president    miners        p  ...          p        one   children
# 2      would    health   people  ...       said  voiceover    longing
# 3       know      coal    would  ...    almonor        new          p
# 4      going      http      one  ...      would       like       know
# 5  voiceover   disease    could  ...        one          p       like
# 6    kennedy       cwp     like  ...  president      would     people
# 7        qwq    states     know  ...         nt    vanocur  voiceover
# 8      years  virginia     life  ...     people     system      could
# 9       time   workers     time  ...      think       even       said
#
#   Topic 194  Topic 195 Topic 196    Topic 197         Topic 198  Topic 199  \
# 0   clemens          p       new            p                nt     johnny
# 1     conan   students         p          ali  secretarygeneral       reed
# 2  pettitte     social       car      cassius             annan        sue
# 3     roger    studies        nt     narrator         voiceover     surfer
# 4      said    student     rifle  heavyweight          ashcraft     silver
# 5   mcnamee        sop      cars        fight           wallace        ben
# 6   goldman   teachers      year     champion               man      hager
# 7     truth  education     price    patterson             right  fantastic
# 8        nt      tasks      like        title              know         nt
# 9     drugs     skills       one       boxing                 1       four
#
#   Topic 200
# 0     think
# 1        nt
# 2     going
# 3    people
# 4      know
# 5      well
# 6       say
# 7       one
# 8       get
# 9     right
#
# [10 rows x 200 columns]

# %%
#Top 3 topics
# Reading the output file generated from the MMSG Topic Model
df_words=pd.read_csv("MMSGTM_ForWords.csv")
df_words.set_index("WORD", inplace = True) 


#Filter top 3 values for every row (11453 words) 

new_df = df.apply(lambda s, n: pd.Series(s.nlargest(n).index), axis=1, n=3)

#Saving the result in excel file
new_df.to_excel (r'top3_topics.xlsx', index = True, header=True)

# %%
df_words
# Out:
#                    Topic 1  Topic 2  Topic 3  Topic 4  Topic 5  Topic 6  \
# WORD
# section                  0        0        0        0        0        1
# issues                   0        2        1        0        0        9
# p                       64      138       14       23        3      109
# allan                    0        0        0        0        0        2
# bloom                    0        0        0        0        0        0
# ...                    ...      ...      ...      ...      ...      ...
# jancrawford              0        0        0        0        0        0
# ricktigner               0        0        0        0        0        0
# bobsimon                 0        0        0        0        0        0
# tompapa                  0        0        0        0        0        0
# elizabethbernstei        0        0        0        0        0        0
#
#                    Topic 7  Topic 8  Topic 9  Topic 10  ...  Topic 191  \
# WORD                                                    ...
# section                  0        0        4         0  ...          1
# issues                   0        0        1         3  ...          6
# p                       64       14      136       147  ...         50
# allan                    0        0        0         0  ...          0
# bloom                    0        0        0         0  ...          0
# ...                    ...      ...      ...       ...  ...        ...
# jancrawford              0        0        0         0  ...          0
# ricktigner               0        0        0         0  ...          0
# bobsimon                 0        0        0         0  ...          0
# tompapa                  0        0        0         0  ...          0
# elizabethbernstei        0        0        0         0  ...          0
#
#                    Topic 192  Topic 193  Topic 194  Topic 195  Topic 196  \
# WORD
# section                    0          0          0         13          0
# issues                     0          0          1         22          0
# p                         37         24          4        183         69
# allan                      0          0          0          0          1
# bloom                      0          0          0          0          0
# ...                      ...        ...        ...        ...        ...
# jancrawford                0          0          0          0          0
# ricktigner                 0          0          0          0          0
# bobsimon                   0          0          0          0          0
# tompapa                    0          0          0          0          0
# elizabethbernstei          0          0          0          0          0
#
#                    Topic 197  Topic 198  Topic 199  Topic 200
# WORD
# section                    0          0          0          0
# issues                     0          0          0          7
# p                         91          0          2          3
# allan                      0          0          0          0
# bloom                      0          0          0          0
# ...                      ...        ...        ...        ...
# jancrawford                0          0          0          2
# ricktigner                 0          0          0          0
# bobsimon                   0          0          0          0
# tompapa                    0          0          0          0
# elizabethbernstei          0          0          0          0
#
# [11453 rows x 200 columns]
